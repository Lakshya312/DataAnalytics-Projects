# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt # we will use this for plotting today

#Loading data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#cleaning data
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# ...

# %%
x = [1,2,3,4]
y = [1,2,3,4]

plt.plot(x,y)
#plt.show()#remove the top number

# %% [markdown]
# #plotting job post dates

# %%
df['job_posted_date'].head()
# Out:
# 0   2023-06-16 13:44:15
# 1   2023-01-14 13:18:07
# 2   2023-10-10 13:14:55
# 3   2023-07-04 13:01:41
# 4   2023-08-07 14:29:36
# Name: job_posted_date, dtype: datetime64[ns]

# %%
date_counts = df['job_posted_date'].value_counts()
date_counts = date_counts.sort_index()

# %%
date_counts
# Out:
# job_posted_date
# 2023-01-01 00:00:04    1
# 2023-01-01 00:00:07    1
# 2023-01-01 00:00:22    1
# 2023-01-01 00:00:24    1
# 2023-01-01 00:00:27    1
#                       ..
# 2023-12-31 23:40:18    2
# 2023-12-31 23:40:22    2
# 2023-12-31 23:40:31    2
# 2023-12-31 23:40:32    1
# 2023-12-31 23:59:58    2
# Name: count, Length: 607192, dtype: int64

# %%
plt.plot(date_counts.index, date_counts)

# %%
df['job_posted_month'] = df['job_posted_date'].dt.month

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
monthly_count = df['job_posted_month'].value_counts()
monthly_count = monthly_count.sort_index()

# %%
monthly_count
# Out:
# job_posted_month
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: count, dtype: int64

# %%
plt.plot(monthly_count.index, monthly_count)

# %% [markdown]
# #Bar Chart- counts of job postings

# %%
job_counts = df['job_title_short'].value_counts()

# %%
plt.bar(job_counts.index, job_counts)
# Out:
# <BarContainer object of 10 artists>

# %%
job_counts = job_counts.sort_values(ascending=True)
plt.barh(job_counts.index, job_counts)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# #home work

# %% [markdown]
# #🟩 Job Country Bar Chart (1.29.1)

# %%
job_country = df['job_country'].value_counts()
job_country = job_country.sort_values(ascending=True).head(10)
job_country
# Out:
# job_country
# Maldives                    2
# Bhutan                      3
# Lesotho                     3
# Mauritania                  3
# Guinea                      4
# Northern Mariana Islands    4
# Gambia                      5
# Papua New Guinea            6
# Curaçao                     7
# Guadeloupe                  7
# Name: count, dtype: int64

# %%
plt.barh(job_country.index, job_country)
plt.show()

# %% [markdown]
# #🟨 Average Salary Horizontal Bar Chart (1.29.2)

# %%
yearly_salary = df['salary_year_avg'].value_counts().head(20)
yearly_salary = yearly_salary.sort_index(ascending=True)
yearly_salary
# Out:
# salary_year_avg
# 70000.0      246
# 75000.0      235
# 79200.0      281
# 80000.0      219
# 89100.0      301
# 90000.0     1070
# 100000.0     435
# 105000.0     248
# 110000.0     297
# 111175.0     321
# 115000.0     790
# 120000.0     284
# 125000.0     786
# 130000.0     239
# 135000.0     261
# 140000.0     321
# 147500.0     641
# 150000.0     645
# 157500.0     444
# 175000.0     299
# Name: count, dtype: int64

# %%
plt.barh(yearly_salary, yearly_salary.index)
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# #🟥 Average Salary Trend Line Plot (1.29.3)

# %%
plt.plot(yearly_salary.index, yearly_salary)
