# %%
import pandas as pd
from datasets import load_dataset

#Loading data
df = load_dataset('lukebarousse/data_jobs')
dataset = df['train'].to_pandas()

# %%
dataset.head(7)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
#
#                    job_location             job_via         job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby                 Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México                 Full-time
# 2               Berlin, Germany        via LinkedIn                 Full-time
# ...

# %%
dataset.tail(7)
# Out:
#              job_title_short  \
# 785734      Business Analyst
# 785735  Senior Data Engineer
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 785734                                  PreSales Engineer
# 785735                               Senior Data Engineer
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                     job_via  \
# 785734                   Almaty, Kazakhstan               melalui Melga
# 785735                       Berlin, Jerman  melalui Top County Careers
# ...

# %%
dataset[['job_title_short', 'salary_year_avg']].head(20)
# Out:
#          job_title_short  salary_year_avg
# 0   Senior Data Engineer              NaN
# 1           Data Analyst              NaN
# 2          Data Engineer              NaN
# 3          Data Engineer              NaN
# 4          Data Engineer              NaN
# 5          Data Engineer              NaN
# 6   Senior Data Engineer              NaN
# 7          Data Engineer              NaN
# 8       Business Analyst              NaN
# 9         Data Scientist              NaN
# 10         Data Engineer              NaN
# 11         Data Engineer              NaN
# 12          Data Analyst              NaN
# 13  Senior Data Engineer              NaN
# 14         Data Engineer              NaN
# 15         Data Engineer              NaN
# 16         Data Engineer              NaN
# 17        Data Scientist              NaN
# 18          Data Analyst              NaN
# 19        Data Scientist              NaN

# %%
dataset[['job_title_short', 'job_title']].iloc[90:100, 0:2]
# Out:
#          job_title_short                                          job_title  \
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
#
#                   job_location
# 90                   Australia
# 91               Temuco, Chile
# 92                    Anywhere
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
dataset.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
dataset['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %% [markdown]
# ---

# %%
dataset[(dataset['job_title_short'] == 'Data Analyst') & (dataset['salary_year_avg'].notna())][['job_title_short', 'salary_year_avg']]
# Out:
#        job_title_short  salary_year_avg
# 109       Data Analyst          89000.0
# 180       Data Analyst          90250.0
# 410       Data Analyst         133285.0
# 988       Data Analyst          62623.0
# 1413      Data Analyst          71300.0
# ...                ...              ...
# 784033    Data Analyst         111175.0
# 784423    Data Analyst          80850.0
# 784882    Data Analyst          87500.0
# 785187    Data Analyst         111175.0
# 785515    Data Analyst         105000.0
#
# [5451 rows x 2 columns]

# %%
dataset['salary_year_avg'].notna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: salary_year_avg, Length: 785741, dtype: bool

# %%
dataset['salary_year_avg'][dataset['salary_year_avg'].notna()]
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64
