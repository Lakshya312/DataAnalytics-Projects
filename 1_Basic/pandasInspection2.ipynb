# %% [markdown]
# #hw-- pandas inspection

# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df.head()
# Out:
#         job_title_short  ...                                    job_type_skills
# 0  Senior Data Engineer  ...                                               None
# 1          Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2         Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3         Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4         Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
#
# [5 rows x 17 columns]

# %% [markdown]
# #🟩 Access Third Row (1.24.1)

# %%
df.iloc[2]
# Out:
# job_title_short                                              Data Engineer
# job_title                Data Engineer/Scientist/Analyst, Mid or Senior...
# job_location                                               Berlin, Germany
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                    Germany
# job_posted_date                                        2023-10-10 13:14:55
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                        Germany
# salary_rate                                                           None
# salary_year_avg                                                        NaN
# salary_hour_avg                                                        NaN
# company_name                                      ALPHA Augmented Services
# job_skills               ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# job_type_skills          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# Name: 2, dtype: object

# %%
df.iloc[20:100, 0:5]
# Out:
#               job_title_short  ...         job_schedule_type
# 20             Data Scientist  ...                 Full-time
# 21             Data Scientist  ...                 Full-time
# 22              Data Engineer  ...                 Full-time
# 23  Machine Learning Engineer  ...                 Full-time
# 24             Data Scientist  ...                 Full-time
# ..                        ...  ...                       ...
# 95              Data Engineer  ...                 Full-time
# 96              Data Engineer  ...                 Full-time
# 97               Data Analyst  ...  Full-time and Contractor
# 98       Senior Data Engineer  ...                 Full-time
# 99              Data Engineer  ...                 Full-time
#
# [80 rows x 5 columns]

# %% [markdown]
# #🟨 Unique Job Countries (1.24.2)

# %%
df['job_location'].unique()
# Out:
# array(['Watertown, CT', 'Guadalajara, Jalisco, Mexico', 'Berlin, Germany',
#        ..., 'Heidelberg, Jerman', 'Bad Rodach, Jerman',
#        'Newark, New Jersey, Amerika Serikat'], dtype=object)

# %% [markdown]
# #🟨 Filter by Job Schedule Type and Display (1.24.3)

# %%
filter = df['job_schedule_type'] == 'Full-time' # now filter =  [True, False, True, True, False, ...]
df[filter]
# Out:
#              job_title_short  ...                                    job_type_skills
# 0       Senior Data Engineer  ...                                               None
# 1               Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2              Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3              Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4              Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                      ...  ...                                                ...
# 785702      Business Analyst  ...                                               None
# 785703          Data Analyst  ...                                               None
# 785704      Business Analyst  ...                                               None
# 785705          Data Analyst  ...  {'analyst_tools': ['tableau'], 'programming': ...
# 785706         Data Engineer  ...  {'analyst_tools': ['power bi'], 'cloud': ['azu...
#
# [701727 rows x 17 columns]

# %% [markdown]
# #🟥 Check Missing Values (1.24.4)

# %%
df.isnull()
# Out:
#         job_title_short  job_title  ...  job_skills  job_type_skills
# 0                 False      False  ...        True             True
# 1                 False      False  ...       False            False
# 2                 False      False  ...       False            False
# 3                 False      False  ...       False            False
# 4                 False      False  ...       False            False
# ...                 ...        ...  ...         ...              ...
# 785736            False      False  ...       False            False
# 785737            False      False  ...       False            False
# 785738            False      False  ...       False            False
# 785739            False      False  ...       False            False
# 785740            False      False  ...       False            False
#
# [785741 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# job_title_short               0
# job_title                     1
# job_location               1045
# job_via                       8
# job_schedule_type         12667
# job_work_from_home            0
# search_location               0
# job_posted_date               0
# job_no_degree_mention         0
# job_health_insurance          0
# job_country                  49
# salary_rate              752674
# salary_year_avg          763738
# salary_hour_avg          775079
# company_name                 18
# job_skills               117037
# job_type_skills          117037
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(2539353)
