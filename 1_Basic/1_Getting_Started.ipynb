# %%
2 + 3
# Out:
# 5

# %% [markdown]
# ***Alright let's get down to business***
#
# 1.   My first code
# 2.   It's done 😅

# %%
5 * 7
# Out:
# 35

# %%
2 + 2
3 * 9
# Out:
# 27

# %%
print(2 + 2, 3 * 9)
# Out:
# 4 27

# %% [markdown]
# ## **My comment**

# %%
# This is a comment

# %% [markdown]
# This is a normal text
#
# # Heading
#
# **bold**
#
#
#
# 1.   one
#
# 1.   two
# 2.   three
#
#
# 2.   four
#
# [Here is more info on Markdonwn](https://markdownguide.offshoot.io/basic-syntax/)
